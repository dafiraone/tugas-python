# %%
import pandas as pd
# pd.set_option('display.max_rows', 810)
# pd.set_option('display.max_columns', 5)

df_gempa = pd.read_excel('/Dataset/bpbd-od_17602_jml_kejadian_bencana_gempa_bumi__kabupatenkota_data.xlsx')
df_banjir = pd.read_excel('/Dataset/bpbd-od_17600_jml_kejadian_bencana_banjir__kabupatenkota_data.xlsx')
df_longsor = pd.read_excel('/Dataset/bpbd-od_17606_jml_kejadian_bencana_tanah_longsor__kabupatenkota_data.xlsx')

# df = pd.concat([df_gempa, df_banjir, df_longsor])
df = pd.merge(df_gempa, df_banjir, on=('id', 'kode_provinsi', 'nama_provinsi', 'kode_kabupaten_kota', 'nama_kabupaten_kota', 'satuan', 'tahun'), how='inner')
df = pd.merge(df, df_longsor, on=('id', 'kode_provinsi', 'nama_provinsi', 'kode_kabupaten_kota', 'nama_kabupaten_kota', 'satuan', 'tahun'), how='inner')
df = df.fillna(0)
df

# df_gempa['bahaya_kejadian'] = df_gempa['jumlah_gempa_bumi'].apply(lambda jumlah : 'Bahaya' if jumlah > 1 else 'Siaga')
# df_gempa

# numbers = [1,2,3,4,5]
# doubled_numbers_map = list(map(lambda x: x*2, numbers))
# doubled_numbers_map

# doubled_numbers_for = []
# for num in numbers:
#     doubled_numbers_for.append(num*2)

# doubled_numbers_while = []
# index = 0
# while index < len(numbers):
#     doubled_numbers_while.append(numbers[index]*2)
#     index+=1

# print(doubled_numbers_map)
# print(doubled_numbers_for)
# print(doubled_numbers_while)
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 265  266             32    JAWA BARAT                 3275
# 266  267             32    JAWA BARAT                 3276
# 267  268             32    JAWA BARAT                 3277
# 268  269             32    JAWA BARAT                 3278
# 269  270             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_gempa_bumi    satuan  tahun  jumlah_banjir  \
# 0       KABUPATEN BOGOR                  3  KEJADIAN   2012              0
# 1    KABUPATEN SUKABUMI                 41  KEJADIAN   2012             20
# ...

# %%
data = {
    'nama' : ('Daffa', 'Junior', 'Irawan'),
    'umur' : (19, 40, 32),
    'gaji' : (5, 10, 30),
}

df_data = pd.DataFrame(data)

# def kategori_umur(umur):
#     if umur < 25:
#         return 'Muda'
#     elif 25 <= umur < 40:
#         return 'Dewasa'
#     else:
#         return 'Tua'

# df_data['kategori_umur'] = df_data['umur'].apply(kategori_umur)
# df_data

for index, row in df_data.iterrows():
    df_data.at[index, 'gaji'] = row['gaji'] * row(['gaji'] * 0.1)

print('Dataframe setelah penambahan bonus:')
print(df_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Pemrograman Dasar\Python\20-11.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/e%3A/Pemrograman%20Dasar/Python/20-11.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> # def kategori_umur(umur):
#      <a href='vscode-notebook-cell:/e%3A/Pemrograman%20Dasar/Python/20-11.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> #     if umur < 25:
#      <a href='vscode-notebook-cell:/e%3A/Pemrograman%20Dasar/Python/20-11.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> #         return 'Muda'
#    (...)
#      <a href='vscode-notebook-cell:/e%3A/Pemrograman%20Dasar/Python/20-11.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a> # df_data['kategori_umur'] = df_data['umur'].apply(kategori_umur)
#      <a href='vscode-notebook-cell:/e%3A/Pemrograman%20Dasar/Python/20-11.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a> # df_data
# ...
