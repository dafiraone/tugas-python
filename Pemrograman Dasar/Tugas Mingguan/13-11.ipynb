# %%
import pandas as pd

data1 = pd.read_excel("Dataset/bpbd-od_17599_jml_kejadian_bencana_angin_topanangin_puting_beliung___data.xlsx")

data2 = pd.read_excel("Dataset/bps-od_18026_indeks_kedalaman_kemiskinan_berdasarkan_kabupatenkota_data.xlsx")

data3 = pd.read_excel("Dataset/dpmdes-idm_jml_kejadian_bencana_tanah_longsor__des_kel_data.xlsx")

# %%
df = pd.DataFrame(data1)

df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    jumlah_puting_beliung    satuan  tahun
# 0                      2  KEJADIAN   2012
# 1                     27  KEJADIAN   2012
# 2                     23  KEJADIAN   2012
# 3                      3  KEJADIAN   2012
# 4                     28  KEJADIAN   2012

# %%
# df['kolom'].apply(func)
# df = df.drop(['nama_provinsi'], axis=1)
# df.drop_duplicates()
df = df.rename(columns={'kode_provinsi':'Kode Provinsi', 'nama_kabupaten_kota': 'Nama Kabupaten/Kota'})
df.sort_values('Nama Kabupaten/Kota', ascending=False)
# Out:
#       id  Kode Provinsi  kode_kabupaten_kota Nama Kabupaten/Kota  \
# 133  134             32                 3278    KOTA TASIKMALAYA
# 79    80             32                 3278    KOTA TASIKMALAYA
# 187  188             32                 3278    KOTA TASIKMALAYA
# 25    26             32                 3278    KOTA TASIKMALAYA
# 52    53             32                 3278    KOTA TASIKMALAYA
# ..   ...            ...                  ...                 ...
# 111  112             32                 3204   KABUPATEN BANDUNG
# 138  139             32                 3204   KABUPATEN BANDUNG
# 246  247             32                 3204   KABUPATEN BANDUNG
# 165  166             32                 3204   KABUPATEN BANDUNG
# 84    85             32                 3204   KABUPATEN BANDUNG
#
#      jumlah_puting_beliung    satuan  tahun
# 133                     13  KEJADIAN   2016
# 79                       1  KEJADIAN   2014
# 187                     31  KEJADIAN   2018
# ...

# %%
# df['Kode Provinsi']
df[['Kode Provinsi', 'jumlah_puting_beliung']]
df.iloc[2, 2]
df.loc[2, 'Kode Provinsi']
df = df[df['jumlah_puting_beliung'] > 0]
df.sort_values('jumlah_puting_beliung')
# Out:
#       id  Kode Provinsi  kode_kabupaten_kota      Nama Kabupaten/Kota  \
# 173  174             32                 3212      KABUPATEN INDRAMAYU
# 238  239             32                 3275              KOTA BEKASI
# 124  125             32                 3217  KABUPATEN BANDUNG BARAT
# 248  249             32                 3206    KABUPATEN TASIKMALAYA
# 56    57             32                 3203        KABUPATEN CIANJUR
# ..   ...            ...                  ...                      ...
# 207  208             32                 3271               KOTA BOGOR
# 244  245             32                 3202       KABUPATEN SUKABUMI
# 189  190             32                 3201          KABUPATEN BOGOR
# 216  217             32                 3201          KABUPATEN BOGOR
# 243  244             32                 3201          KABUPATEN BOGOR
#
#      jumlah_puting_beliung    satuan  tahun
# 173                      1  KEJADIAN   2018
# ...

# %%
# pd.concat([df1.df2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Pemrograman Dasar\Python\13-11.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Pemrograman%20Dasar/Python/13-11.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> pd.concat(['Nama Kabupaten/Kota', 'jumlah_puting_beliung'])
#
# File e:\Pemrograman Dasar\Python\pemdas\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
# ...

# %%
pembelian_pelanggan = [1,2,3,4,5]

if len(pembelian_pelanggan) > 3:
    print("Anda dapat diskon 10% pada pembelian selanjutnya")
else:
    print("Anda belum mencapai jumlah pembalian yang dibutuhkan")
# Out:
# Anda dapat diskon 10% pada pembelian selanjutnya
